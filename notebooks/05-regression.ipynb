# %%
# I will need to go back and look at the original on github
import pandas as pd
import seaborn as sns

# %%
tips = pd.read_csv('../data/tips.csv')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_dummy = tips[['tip', 'total_bill', 'sex']]

# %%
tips_dummy.head()
# Out:
#     tip  total_bill     sex
# 0  1.01       16.99  Female
# 1  1.66       10.34    Male
# 2  3.50       21.01    Male
# 3  3.31       23.68    Male
# 4  3.61       24.59  Female

# %%
pd.get_dummies(tips_dummy, drop_first=True)
# Out:
#       tip  total_bill  sex_Male
# 0    1.01       16.99         0
# 1    1.66       10.34         1
# 2    3.50       21.01         1
# 3    3.31       23.68         1
# 4    3.61       24.59         0
# 5    4.71       25.29         1
# 6    2.00        8.77         1
# 7    3.12       26.88         1
# 8    1.96       15.04         1
# 9    3.23       14.78         1
# 10   1.71       10.27         1
# 11   5.00       35.26         0
# 12   1.57       15.42         1
# 13   3.00       18.43         1
# 14   3.02       14.83         0
# 15   3.92       21.58         1
# 16   1.67       10.33         0
# 17   3.71       16.29         1
# 18   3.50       16.97         0
# 19   3.35       20.65         1
# 20   4.08       17.92         1
# 21   2.75       20.29         0
# 22   2.23       15.77         0
# 23   7.58       39.42         1
# 24   3.18       19.82         1
# 25   2.34       17.81         1
# 26   2.00       13.37         1
# 27   2.00       12.69         1
# ...
